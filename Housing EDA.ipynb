# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv(r'~/Desktop/housing/train.csv', index_col=0)
test = pd.read_csv(r'~/Desktop/housing/test.csv', index_col=0)
train.shape, test.shape
# Out:
# ((1460, 80), (1459, 79))

# %%
x = train['LotArea']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'brown')

# %%
x = train['GrLivArea']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'green')

# %%
x = train['KitchenQual']
y = train['SalePrice']

sns.swarmplot(x, y, data = train)

# %%
x = train['OverallQual']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'gold')

# %%
train.groupby('OverallQual')['SalePrice'].agg(np.mean).sort_values(ascending = False)
# Out:
# OverallQual
# 10    438588.388889
# 9     367513.023256
# 8     274735.535714
# 7     207716.423197
# 6     161603.034759
# 5     133523.347607
# 4     108420.655172
# 3      87473.750000
# 2      51770.333333
# 1      50150.000000
# Name: SalePrice, dtype: float64

# %%
x = train['OverallCond']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'silver')
# Out:
# (<matplotlib.collections.PathCollection at 0x1a18330ed0>,
#  <matplotlib.collections.PathCollection at 0x1a18354b90>)

# %%
train.groupby('OverallCond')['SalePrice'].agg(np.mean).sort_values(ascending = False)
# Out:
# OverallCond
# 9    216004.545455
# 5    203146.914738
# 7    158145.487805
# 8    155651.736111
# 6    153961.591270
# 2    141986.400000
# 4    120438.438596
# 3    101929.400000
# 1     61000.000000
# Name: SalePrice, dtype: float64

# %%
x = train['MoSold']
plt.hist(x, color = 'black', bins = 30, density = True)
plt.xlabel('Month sold')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
x = train['MoSold']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'black')

# %%
x = train['GarageArea']
y = train['SalePrice']
plt.scatter(x, y, marker = 'o', color = 'black')
